# %%
import numpy as np
import json
from scipy.spatial.distance import cdist

# Load the necessary data files
with open('../../model/documents_dict.json', 'r', encoding='utf-8') as f:
    documents = json.load(f)

with open('../../model/encoded_segments.json', 'r', encoding='utf-8') as f:
    encoded_segments = json.load(f)

with open('../../model/segment_encodings.json', 'r', encoding='utf-8') as f:
    segment_encodings = json.load(f)  

with open('../../model/sat_segments_dict.json', 'r', encoding='utf-8') as f:
    sat_segments_dict = json.load(f)

# %%
# Define the SAT topic
sat_topic = 'referen'

# Creating list of SAT topics.
topics = list(sat_segments_dict.keys())

# %%
total_TP = 0
total_FN = 0
total_FP = 0
total_TN = 0

for sat_topic in topics:    
    # Print selected SAT topic
    print('Selected SAT:', sat_topic)

    # Step 1: Get the encoding vectors for the SAT
    sat_segment_ids = sat_segments_dict[sat_topic]
    sat_segment_indices = [encoded_segments.index(segment_id) for segment_id in sat_segment_ids]
    sat_encodings = [segment_encodings[index] for index in sat_segment_indices]

    print('Number of segments in SAT:', len(sat_segment_ids))
    print()

    # Step 2: Build a similarity matrix with SAT segments in rows and corpus segments in columns
    print('Building matrix…')
    sim_matrix = cdist(sat_encodings, segment_encodings, metric='cosine')  # Cosine similarity
    print('Similarity matrix dimensions:', sim_matrix.shape)
    print()

    # Step 3: Set a similarity threshold for classification
    threshold = 0.8

    # Step 4: Initialize counters for True Positives (TP), False Negatives (FN), False Positives (FP), and True Negatives (TN)
    TP = 0
    FN = 0
    FP = 0
    TN = 0

    # Step 5: For each segment, classify based on similarity threshold
    for idx, sentence_id in enumerate(encoded_segments):
        # Get the similarity values for each SAT segment to the current sentence
        similarities = sim_matrix[:, idx]

        # Segments predicted to be similar (above threshold)
        predicted_similar = similarities >= threshold

        # Segments that are actually part of the SAT topic (actual similar)
        actual_similar = sentence_id in sat_segments_dict[sat_topic]

        # True Positives (TP): Segments that were correctly predicted as similar to the SAT topic
        if predicted_similar.any() and actual_similar:
            TP += 1

        # False Negatives (FN): Segments that are part of the SAT topic but predicted below the threshold
        if not predicted_similar.any() and actual_similar:
            FN += 1

        # False Positives (FP): Segments that were incorrectly predicted as similar to the SAT topic
        if predicted_similar.any() and not actual_similar:
            FP += 1

        # True Negatives (TN): Segments that were correctly predicted as not similar to the SAT topic
        if not predicted_similar.any() and not actual_similar:
            TN += 1

    # Output the results
    print(f"True Positives (TP): {TP}")
    print(f"False Negatives (FN): {FN}")
    print(f"False Positives (FP): {FP}")
    print(f"True Negatives (TN): {TN}")
# Out:
# Selected SAT: referen
# Number of segments in SAT: 348
#
# Building matrix…
# Similarity matrix dimensions: (348, 163596)
#
# True Positives (TP): 348
# False Negatives (FN): 0
# False Positives (FP): 163248
# True Negatives (TN): 0
# Selected SAT: flag
# Number of segments in SAT: 74
#
# Building matrix…
# Similarity matrix dimensions: (74, 163596)
#
# True Positives (TP): 58
# False Negatives (FN): 16
# False Positives (FP): 163482
# True Negatives (TN): 40
# Selected SAT: anthem
# Number of segments in SAT: 79
#
# Building matrix…
# Similarity matrix dimensions: (79, 163596)
#
# True Positives (TP): 63
# False Negatives (FN): 16
# False Positives (FP): 163474
# True Negatives (TN): 43
# Selected SAT: seprel
# Number of segments in SAT: 64
#
# Building matrix…
# Similarity matrix dimensions: (64, 163596)
#
# True Positives (TP): 56
# False Negatives (FN): 8
# False Positives (FP): 163514
# True Negatives (TN): 18
# Selected SAT: freerel
# Number of segments in SAT: 78
#
# Building matrix…
# Similarity matrix dimensions: (78, 163596)
#
# True Positives (TP): 64
# False Negatives (FN): 14
# False Positives (FP): 163485
# True Negatives (TN): 33
# Selected SAT: equalgr5
# Number of segments in SAT: 65
#
# Building matrix…
# Similarity matrix dimensions: (65, 163596)
#
# True Positives (TP): 64
# False Negatives (FN): 1
# False Positives (FP): 163525
# True Negatives (TN): 6
# Selected SAT: equalgr11
# Number of segments in SAT: 71
#
# Building matrix…
# Similarity matrix dimensions: (71, 163596)
#
# True Positives (TP): 67
# False Negatives (FN): 4
# False Positives (FP): 163506
# True Negatives (TN): 19
# Selected SAT: equalgr4
# Number of segments in SAT: 107
#
# Building matrix…
# Similarity matrix dimensions: (107, 163596)
#
# True Positives (TP): 107
# False Negatives (FN): 0
# False Positives (FP): 163489
# True Negatives (TN): 0
# Selected SAT: equalgr15
# Number of segments in SAT: 64
#
# Building matrix…
# Similarity matrix dimensions: (64, 163596)
#
# True Positives (TP): 47
# False Negatives (FN): 17
# False Positives (FP): 163486
# True Negatives (TN): 46
# Selected SAT: equalgr13
# Number of segments in SAT: 53
#
# Building matrix…
# Similarity matrix dimensions: (53, 163596)
#
# True Positives (TP): 53
# False Negatives (FN): 0
# False Positives (FP): 163541
# True Negatives (TN): 2
# Selected SAT: equalgr6
# Number of segments in SAT: 118
#
# Building matrix…
# Similarity matrix dimensions: (118, 163596)
#
# True Positives (TP): 117
# False Negatives (FN): 1
# False Positives (FP): 163478
# True Negatives (TN): 0
# Selected SAT: equalgr16
# Number of segments in SAT: 35
#
# Building matrix…
# Similarity matrix dimensions: (35, 163596)
#
# True Positives (TP): 25
# False Negatives (FN): 10
# False Positives (FP): 163430
# True Negatives (TN): 131
# Selected SAT: equalgr9
# Number of segments in SAT: 42
#
# Building matrix…
# Similarity matrix dimensions: (42, 163596)
#
# True Positives (TP): 42
# False Negatives (FN): 0
# False Positives (FP): 163554
# True Negatives (TN): 0
# Selected SAT: equalgr3
# Number of segments in SAT: 77
#
# Building matrix…
# Similarity matrix dimensions: (77, 163596)
#
# True Positives (TP): 20
# False Negatives (FN): 57
# False Positives (FP): 163268
# True Negatives (TN): 251
# Selected SAT: equalgr12
# Number of segments in SAT: 66
#
# Building matrix…
# Similarity matrix dimensions: (66, 163596)
#
# True Positives (TP): 64
# False Negatives (FN): 2
# False Positives (FP): 163530
# True Negatives (TN): 0
# Selected SAT: equalgr1
# Number of segments in SAT: 160
#
# Building matrix…
# Similarity matrix dimensions: (160, 163596)
#
# True Positives (TP): 160
# False Negatives (FN): 0
# False Positives (FP): 163436
# True Negatives (TN): 0
# Selected SAT: miranda
# Number of segments in SAT: 107
#
# Building matrix…
# Similarity matrix dimensions: (107, 163596)
#
# True Positives (TP): 107
# False Negatives (FN): 0
# False Positives (FP): 163489
# True Negatives (TN): 0
# Selected SAT: couns
# Number of segments in SAT: 212
#
# Building matrix…
# Similarity matrix dimensions: (212, 163596)
#
# True Positives (TP): 212
# False Negatives (FN): 0
# False Positives (FP): 163384
# True Negatives (TN): 0
# Selected SAT: trilang
# Number of segments in SAT: 132
#
# Building matrix…
# Similarity matrix dimensions: (132, 163596)
#
# True Positives (TP): 132
# False Negatives (FN): 0
# False Positives (FP): 163464
# True Negatives (TN): 0
# Selected SAT: appeal
# Number of segments in SAT: 153
#
# Building matrix…
# Similarity matrix dimensions: (153, 163596)
#
# True Positives (TP): 153
# False Negatives (FN): 0
# False Positives (FP): 163443
# True Negatives (TN): 0
# Selected SAT: evidence
# Number of segments in SAT: 145
#
# Building matrix…
# Similarity matrix dimensions: (145, 163596)
#
# True Positives (TP): 145
# False Negatives (FN): 0
# False Positives (FP): 163451
# True Negatives (TN): 0
# Selected SAT: fairtri
# Number of segments in SAT: 102
#
# Building matrix…
# Similarity matrix dimensions: (102, 163596)
#
# True Positives (TP): 100
# False Negatives (FN): 2
# False Positives (FP): 163491
# True Negatives (TN): 3
# Selected SAT: resenex
# Number of segments in SAT: 55
#
# Building matrix…
# Similarity matrix dimensions: (55, 163596)
#
# True Positives (TP): 55
# False Negatives (FN): 0
# False Positives (FP): 163541
# True Negatives (TN): 0
# Selected SAT: infoacc
# Number of segments in SAT: 59
#
# Building matrix…
# Similarity matrix dimensions: (59, 163596)
#
# True Positives (TP): 59
# False Negatives (FN): 0
# False Positives (FP): 163537
# True Negatives (TN): 0
# Selected SAT: opinion
# Number of segments in SAT: 123
#
# Building matrix…
# Similarity matrix dimensions: (123, 163596)
#
# True Positives (TP): 121
# False Negatives (FN): 2
# False Positives (FP): 163464
# True Negatives (TN): 9
# Selected SAT: parents
# Number of segments in SAT: 172
#
# Building matrix…
# Similarity matrix dimensions: (172, 163596)
#
# True Positives (TP): 155
# False Negatives (FN): 17
# False Positives (FP): 163423
# True Negatives (TN): 1
# Selected SAT: assem
# Number of segments in SAT: 81
#
# Building matrix…
# Similarity matrix dimensions: (81, 163596)
#
# True Positives (TP): 78
# False Negatives (FN): 3
# False Positives (FP): 163505
# True Negatives (TN): 10
# Selected SAT: assoc
# Number of segments in SAT: 98
#
# Building matrix…
# Similarity matrix dimensions: (98, 163596)
#
# True Positives (TP): 96
# False Negatives (FN): 2
# False Positives (FP): 163496
# True Negatives (TN): 2
# Selected SAT: milrest
# Number of segments in SAT: 121
#
# Building matrix…
# Similarity matrix dimensions: (121, 163596)
#
# True Positives (TP): 121
# False Negatives (FN): 0
# False Positives (FP): 163475
# True Negatives (TN): 0
# Selected SAT: voteun
# Number of segments in SAT: 190
#
# Building matrix…
# Similarity matrix dimensions: (190, 163596)
#
# True Positives (TP): 187
# False Negatives (FN): 3
# False Positives (FP): 163398
# True Negatives (TN): 8
# Selected SAT: slave
# Number of segments in SAT: 74
#
# Building matrix…
# Similarity matrix dimensions: (74, 163596)
#
# True Positives (TP): 74
# False Negatives (FN): 0
# False Positives (FP): 163521
# True Negatives (TN): 1
# Selected SAT: finsup3
# Number of segments in SAT: 109
#
# Building matrix…
# Similarity matrix dimensions: (109, 163596)
#
# True Positives (TP): 109
# False Negatives (FN): 0
# False Positives (FP): 163487
# True Negatives (TN): 0
# Selected SAT: matequal
# Number of segments in SAT: 65
#
# Building matrix…
# Similarity matrix dimensions: (65, 163596)
#
# True Positives (TP): 55
# False Negatives (FN): 10
# False Positives (FP): 163527
# True Negatives (TN): 4
# Selected SAT: edfree
# Number of segments in SAT: 131
#
# Building matrix…
# Similarity matrix dimensions: (131, 163596)
#
# True Positives (TP): 106
# False Negatives (FN): 25
# False Positives (FP): 163438
# True Negatives (TN): 27
# Selected SAT: edcomp
# Number of segments in SAT: 98
#
# Building matrix…
# Similarity matrix dimensions: (98, 163596)
#
# True Positives (TP): 65
# False Negatives (FN): 33
# False Positives (FP): 163476
# True Negatives (TN): 22
# Selected SAT: science
# Number of segments in SAT: 290
#
# Building matrix…
# Similarity matrix dimensions: (290, 163596)
#
# True Positives (TP): 290
# False Negatives (FN): 0
# False Positives (FP): 163306
# True Negatives (TN): 0
# Selected SAT: langprot
# Number of segments in SAT: 89
#
# Building matrix…
# Similarity matrix dimensions: (89, 163596)
#
# True Positives (TP): 89
# False Negatives (FN): 0
# False Positives (FP): 163507
# True Negatives (TN): 0
# Selected SAT: indpolgr6
# Number of segments in SAT: 17
#
# Building matrix…
# Similarity matrix dimensions: (17, 163596)
#
# True Positives (TP): 17
# False Negatives (FN): 0
# False Positives (FP): 163579
# True Negatives (TN): 0
# Selected SAT: indpolgr2
# Number of segments in SAT: 16
#
# Building matrix…
# Similarity matrix dimensions: (16, 163596)
#
# True Positives (TP): 16
# False Negatives (FN): 0
# False Positives (FP): 163576
# True Negatives (TN): 4
# Selected SAT: transfer
# Number of segments in SAT: 82
#
# Building matrix…
# Similarity matrix dimensions: (82, 163596)
#
# True Positives (TP): 79
# False Negatives (FN): 3
# False Positives (FP): 163514
# True Negatives (TN): 0
# Selected SAT: water
# Number of segments in SAT: 45
#
# Building matrix…
# Similarity matrix dimensions: (45, 163596)
#
# True Positives (TP): 45
# False Negatives (FN): 0
# False Positives (FP): 163551
# True Negatives (TN): 0
# Selected SAT: opgroup
# Number of segments in SAT: 28
#
# Building matrix…
# Similarity matrix dimensions: (28, 163596)
#
# True Positives (TP): 28
# False Negatives (FN): 0
# False Positives (FP): 163568
# True Negatives (TN): 0
# Selected SAT: lhseats
# Number of segments in SAT: 118
#
# Building matrix…
# Similarity matrix dimensions: (118, 163596)
#
# True Positives (TP): 118
# False Negatives (FN): 0
# False Positives (FP): 163478
# True Negatives (TN): 0
# Selected SAT: freeelec
# Number of segments in SAT: 192
#
# Building matrix…
# Similarity matrix dimensions: (192, 163596)
#
# True Positives (TP): 114
# False Negatives (FN): 78
# False Positives (FP): 163297
# True Negatives (TN): 107
# Selected SAT: lhselect
# Number of segments in SAT: 177
#
# Building matrix…
# Similarity matrix dimensions: (177, 163596)
#
# True Positives (TP): 177
# False Negatives (FN): 0
# False Positives (FP): 163419
# True Negatives (TN): 0
# Selected SAT: lhquota
# Number of segments in SAT: 66
#
# Building matrix…
# Similarity matrix dimensions: (66, 163596)
#
# True Positives (TP): 66
# False Negatives (FN): 0
# False Positives (FP): 163530
# True Negatives (TN): 0
# Selected SAT: legsupr
# Number of segments in SAT: 77
#
# Building matrix…
# Similarity matrix dimensions: (77, 163596)
#
# True Positives (TP): 77
# False Negatives (FN): 0
# False Positives (FP): 163519
# True Negatives (TN): 0
# Selected SAT: lhterm
# Number of segments in SAT: 128
#
# Building matrix…
# Similarity matrix dimensions: (128, 163596)
#
# True Positives (TP): 124
# False Negatives (FN): 4
# False Positives (FP): 163458
# True Negatives (TN): 10
# Selected SAT: hogterm
# Number of segments in SAT: 32
#
# Building matrix…
# Similarity matrix dimensions: (32, 163596)
#
# True Positives (TP): 32
# False Negatives (FN): 0
# False Positives (FP): 163482
# True Negatives (TN): 82
# Selected SAT: em
# Number of segments in SAT: 393
#
# Building matrix…
# Similarity matrix dimensions: (393, 163596)
#
# True Positives (TP): 393
# False Negatives (FN): 0
# False Positives (FP): 163203
# True Negatives (TN): 0
# Selected SAT: electsch
# Number of segments in SAT: 133
#
# Building matrix…
# Similarity matrix dimensions: (133, 163596)
#
# True Positives (TP): 133
# False Negatives (FN): 0
# False Positives (FP): 163463
# True Negatives (TN): 0
# Selected SAT: lhrest
# Number of segments in SAT: 120
#
# Building matrix…
# Similarity matrix dimensions: (120, 163596)
#
# True Positives (TP): 120
# False Negatives (FN): 0
# False Positives (FP): 163476
# True Negatives (TN): 0
# Selected SAT: profleg
# Number of segments in SAT: 180
#
# Building matrix…
# Similarity matrix dimensions: (180, 163596)
#
# True Positives (TP): 180
# False Negatives (FN): 0
# False Positives (FP): 163416
# True Negatives (TN): 0
# Selected SAT: uhterm
# Number of segments in SAT: 54
#
# Building matrix…
# Similarity matrix dimensions: (54, 163596)
#
# True Positives (TP): 54
# False Negatives (FN): 0
# False Positives (FP): 163533
# True Negatives (TN): 9
# Selected SAT: quorum
# Number of segments in SAT: 82
#
# Building matrix…
# Similarity matrix dimensions: (82, 163596)
#
# True Positives (TP): 79
# False Negatives (FN): 3
# False Positives (FP): 163508
# True Negatives (TN): 6
# Selected SAT: immunity
# Number of segments in SAT: 61
#
# Building matrix…
# Similarity matrix dimensions: (61, 163596)
#
# True Positives (TP): 61
# False Negatives (FN): 0
# False Positives (FP): 163526
# True Negatives (TN): 9
# Selected SAT: hosterml
# Number of segments in SAT: 94
#
# Building matrix…
# Similarity matrix dimensions: (94, 163596)
#
# True Positives (TP): 35
# False Negatives (FN): 59
# False Positives (FP): 162474
# True Negatives (TN): 1028
# Selected SAT: hosterm
# Number of segments in SAT: 109
#
# Building matrix…
# Similarity matrix dimensions: (109, 163596)
#
# True Positives (TP): 97
# False Negatives (FN): 12
# False Positives (FP): 163405
# True Negatives (TN): 82
# Selected SAT: hosrest
# Number of segments in SAT: 128
#
# Building matrix…
# Similarity matrix dimensions: (128, 163596)
#
# True Positives (TP): 128
# False Negatives (FN): 0
# False Positives (FP): 163468
# True Negatives (TN): 0
# Selected SAT: headforn
# Number of segments in SAT: 145
#
# Building matrix…
# Similarity matrix dimensions: (145, 163596)
#
# True Positives (TP): 145
# False Negatives (FN): 0
# False Positives (FP): 163451
# True Negatives (TN): 0
# Selected SAT: pardon
# Number of segments in SAT: 112
#
# Building matrix…
# Similarity matrix dimensions: (112, 163596)
#
# True Positives (TP): 112
# False Negatives (FN): 0
# False Positives (FP): 163484
# True Negatives (TN): 0
# Selected SAT: legdiss
# Number of segments in SAT: 160
#
# Building matrix…
# Similarity matrix dimensions: (160, 163596)
#
# True Positives (TP): 160
# False Negatives (FN): 0
# False Positives (FP): 163436
# True Negatives (TN): 0
# Selected SAT: commit
# Number of segments in SAT: 350
#
# Building matrix…
# Similarity matrix dimensions: (350, 163596)
#
# True Positives (TP): 350
# False Negatives (FN): 0
# False Positives (FP): 163246
# True Negatives (TN): 0
# Selected SAT: cabdiss
# Number of segments in SAT: 300
#
# Building matrix…
# Similarity matrix dimensions: (300, 163596)
#
# True Positives (TP): 300
# False Negatives (FN): 0
# False Positives (FP): 163296
# True Negatives (TN): 0
# Selected SAT: abide
# Number of segments in SAT: 152
#
# Building matrix…
# Similarity matrix dimensions: (152, 163596)
#
# True Positives (TP): 151
# False Negatives (FN): 1
# False Positives (FP): 163441
# True Negatives (TN): 3
# Selected SAT: illadmin
# Number of segments in SAT: 78
#
# Building matrix…
# Similarity matrix dimensions: (78, 163596)
#
# True Positives (TP): 78
# False Negatives (FN): 0
# False Positives (FP): 163518
# True Negatives (TN): 0
# Selected SAT: nomil
# Number of segments in SAT: 51
#
# Building matrix…
# Similarity matrix dimensions: (51, 163596)
#
# True Positives (TP): 46
# False Negatives (FN): 5
# False Positives (FP): 163538
# True Negatives (TN): 7
# Selected SAT: hocage
# Number of segments in SAT: 28
#
# Building matrix…
# Similarity matrix dimensions: (28, 163596)
#
# True Positives (TP): 24
# False Negatives (FN): 4
# False Positives (FP): 163521
# True Negatives (TN): 47
# Selected SAT: judretir
# Number of segments in SAT: 121
#
# Building matrix…
# Similarity matrix dimensions: (121, 163596)
#
# True Positives (TP): 121
# False Negatives (FN): 0
# False Positives (FP): 163475
# True Negatives (TN): 0
# Selected SAT: jc
# Number of segments in SAT: 335
#
# Building matrix…
# Similarity matrix dimensions: (335, 163596)
#
# True Positives (TP): 335
# False Negatives (FN): 0
# False Positives (FP): 163261
# True Negatives (TN): 0
# Selected SAT: balbudgt
# Number of segments in SAT: 20
#
# Building matrix…
# Similarity matrix dimensions: (20, 163596)
#
# True Positives (TP): 16
# False Negatives (FN): 4
# False Positives (FP): 163524
# True Negatives (TN): 52
# Selected SAT: treatcon
# Number of segments in SAT: 181
#
# Building matrix…
# Similarity matrix dimensions: (181, 163596)
#
# True Positives (TP): 181
# False Negatives (FN): 0
# False Positives (FP): 163415
# True Negatives (TN): 0
# Selected SAT: intlaw
# Number of segments in SAT: 752
#
# Building matrix…
# Similarity matrix dimensions: (752, 163596)
#
# True Positives (TP): 752
# False Negatives (FN): 0
# False Positives (FP): 162844
# True Negatives (TN): 0
# Selected SAT: custlaw
# Number of segments in SAT: 82
#
# Building matrix…
# Similarity matrix dimensions: (82, 163596)
#
# True Positives (TP): 81
# False Negatives (FN): 1
# False Positives (FP): 163512
# True Negatives (TN): 2
# Selected SAT: fedsep
# Number of segments in SAT: 58
#
# Building matrix…
# Similarity matrix dimensions: (58, 163596)
#
# True Positives (TP): 58
# False Negatives (FN): 0
# False Positives (FP): 163534
# True Negatives (TN): 4
# Selected SAT: fedrev
# Number of segments in SAT: 91
#
# Building matrix…
# Similarity matrix dimensions: (91, 163596)
#
# True Positives (TP): 91
# False Negatives (FN): 0
# False Positives (FP): 163505
# True Negatives (TN): 0
# Selected SAT: partunco
# Number of segments in SAT: 40
#
# Building matrix…
# Similarity matrix dimensions: (40, 163596)
# True Positives (TP): 40
# False Negatives (FN): 0
# False Positives (FP): 163555
# True Negatives (TN): 1
# Selected SAT: conres
# Number of segments in SAT: 77
#
# Building matrix…
# Similarity matrix dimensions: (77, 163596)
#
# True Positives (TP): 70
# False Negatives (FN): 7
# False Positives (FP): 163494
# True Negatives (TN): 25
# Selected SAT: conlim
# Number of segments in SAT: 40
#
# Building matrix…
# Similarity matrix dimensions: (40, 163596)
#
# True Positives (TP): 32
# False Negatives (FN): 8
# False Positives (FP): 163437
# True Negatives (TN): 119
# Selected SAT: conterm
# Number of segments in SAT: 66
#
# Building matrix…
# Similarity matrix dimensions: (66, 163596)
#
# True Positives (TP): 31
# False Negatives (FN): 35
# False Positives (FP): 163381
# True Negatives (TN): 149
# Selected SAT: dignity
# Number of segments in SAT: 275
#
# Building matrix…
# Similarity matrix dimensions: (275, 163596)
#
# True Positives (TP): 275
# False Negatives (FN): 0
# False Positives (FP): 163321
# True Negatives (TN): 0
# Selected SAT: region
# Number of segments in SAT: 131
#
# Building matrix…
# Similarity matrix dimensions: (131, 163596)
#
# True Positives (TP): 131
# False Negatives (FN): 0
# False Positives (FP): 163465
# True Negatives (TN): 0
# Selected SAT: intrght
# Number of segments in SAT: 104
#
# Building matrix…
# Similarity matrix dimensions: (104, 163596)
#
# True Positives (TP): 104
# False Negatives (FN): 0
# False Positives (FP): 163492
# True Negatives (TN): 0
# Selected SAT: env
# Number of segments in SAT: 342
#
# Building matrix…
# Similarity matrix dimensions: (342, 163596)
#
# True Positives (TP): 342
# False Negatives (FN): 0
# False Positives (FP): 163254
# True Negatives (TN): 0
# Selected SAT: equalgr10
# Number of segments in SAT: 45
#
# Building matrix…
# Similarity matrix dimensions: (45, 163596)
#
# True Positives (TP): 45
# False Negatives (FN): 0
# False Positives (FP): 163551
# True Negatives (TN): 0
# Selected SAT: life
# Number of segments in SAT: 79
#
# Building matrix…
# Similarity matrix dimensions: (79, 163596)
#
# True Positives (TP): 78
# False Negatives (FN): 1
# False Positives (FP): 163515
# True Negatives (TN): 2
# Selected SAT: cruelty
# Number of segments in SAT: 119
#
# Building matrix…
# Similarity matrix dimensions: (119, 163596)
#
# True Positives (TP): 119
# False Negatives (FN): 0
# False Positives (FP): 163473
# True Negatives (TN): 4
# Selected SAT: torture
# Number of segments in SAT: 115
#
# Building matrix…
# Similarity matrix dimensions: (115, 163596)
#
# True Positives (TP): 114
# False Negatives (FN): 1
# False Positives (FP): 163478
# True Negatives (TN): 3
# Selected SAT: citdep
# Number of segments in SAT: 54
#
# Building matrix…
# Similarity matrix dimensions: (54, 163596)
#
# True Positives (TP): 33
# False Negatives (FN): 21
# False Positives (FP): 163459
# True Negatives (TN): 83
# Selected SAT: presinoc
# Number of segments in SAT: 128
#
# Building matrix…
# Similarity matrix dimensions: (128, 163596)
#
# True Positives (TP): 105
# False Negatives (FN): 23
# False Positives (FP): 163405
# True Negatives (TN): 63
# Selected SAT: cultrght
# Number of segments in SAT: 211
#
# Building matrix…
# Similarity matrix dimensions: (211, 163596)
#
# True Positives (TP): 211
# False Negatives (FN): 0
# False Positives (FP): 163385
# True Negatives (TN): 0
# Selected SAT: conpow
# Number of segments in SAT: 154
#
# Building matrix…
# Similarity matrix dimensions: (154, 163596)
#
# True Positives (TP): 154
# False Negatives (FN): 0
# False Positives (FP): 163442
# True Negatives (TN): 0
# Selected SAT: oath
# Number of segments in SAT: 228
#
# Building matrix…
# Similarity matrix dimensions: (228, 163596)
#
# True Positives (TP): 228
# False Negatives (FN): 0
# False Positives (FP): 163368
# True Negatives (TN): 0
# Selected SAT: hogdiss
# Number of segments in SAT: 168
#
# Building matrix…
# Similarity matrix dimensions: (168, 163596)
#
# True Positives (TP): 168
# False Negatives (FN): 0
# False Positives (FP): 163428
# True Negatives (TN): 0
# Selected SAT: hogelect
# Number of segments in SAT: 156
#
# Building matrix…
# Similarity matrix dimensions: (156, 163596)
#
# True Positives (TP): 156
# False Negatives (FN): 0
# False Positives (FP): 163440
# True Negatives (TN): 0
# Selected SAT: hogrest
# Number of segments in SAT: 69
#
# Building matrix…
# Similarity matrix dimensions: (69, 163596)
#
# True Positives (TP): 69
# False Negatives (FN): 0
# False Positives (FP): 163527
# True Negatives (TN): 0
# Selected SAT: hosstaff
# Number of segments in SAT: 116
#
# Building matrix…
# Similarity matrix dimensions: (116, 163596)
#
# True Positives (TP): 116
# False Negatives (FN): 0
# False Positives (FP): 163480
# True Negatives (TN): 0
# Selected SAT: comchief
# Number of segments in SAT: 157
#
# Building matrix…
# Similarity matrix dimensions: (157, 163596)
#
# True Positives (TP): 157
# False Negatives (FN): 0
# False Positives (FP): 163439
# True Negatives (TN): 0
# Selected SAT: execnum
# Number of segments in SAT: 146
#
# Building matrix…
# Similarity matrix dimensions: (146, 163596)
#
# True Positives (TP): 146
# False Negatives (FN): 0
# False Positives (FP): 163450
# True Negatives (TN): 0
# Selected SAT: cabrest
# Number of segments in SAT: 173
#
# Building matrix…
# Similarity matrix dimensions: (173, 163596)
#
# True Positives (TP): 173
# False Negatives (FN): 0
# False Positives (FP): 163423
# True Negatives (TN): 0
# Selected SAT: hoglegr
# Number of segments in SAT: 61
#
# Building matrix…
# Similarity matrix dimensions: (61, 163596)
#
# True Positives (TP): 59
# False Negatives (FN): 2
# False Positives (FP): 163460
# True Negatives (TN): 75
# Selected SAT: legrep
# Number of segments in SAT: 99
#
# Building matrix…
# Similarity matrix dimensions: (99, 163596)
#
# True Positives (TP): 99
# False Negatives (FN): 0
# False Positives (FP): 163496
# True Negatives (TN): 1
# Selected SAT: income
# Number of segments in SAT: 44
#
# Building matrix…
# Similarity matrix dimensions: (44, 163596)
#
# True Positives (TP): 44
# False Negatives (FN): 0
# False Positives (FP): 163552
# True Negatives (TN): 0
# Selected SAT: remleg
# Number of segments in SAT: 105
#
# Building matrix…
# Similarity matrix dimensions: (105, 163596)
#
# True Positives (TP): 105
# False Negatives (FN): 0
# False Positives (FP): 163491
# True Negatives (TN): 0
# Selected SAT: orglaw
# Number of segments in SAT: 33
#
# Building matrix…
# Similarity matrix dimensions: (33, 163596)
#
# True Positives (TP): 33
# False Negatives (FN): 0
# False Positives (FP): 163563
# True Negatives (TN): 0
# Selected SAT: legini
# Number of segments in SAT: 135
#
# Building matrix…
# Similarity matrix dimensions: (135, 163596)
#
# True Positives (TP): 135
# False Negatives (FN): 0
# False Positives (FP): 163461
# True Negatives (TN): 0
# Selected SAT: stdcom
# Number of segments in SAT: 124
#
# Building matrix…
# Similarity matrix dimensions: (124, 163596)
#
# True Positives (TP): 124
# False Negatives (FN): 0
# False Positives (FP): 163472
# True Negatives (TN): 0
# Selected SAT: initiat
# Number of segments in SAT: 44
#
# Building matrix…
# Similarity matrix dimensions: (44, 163596)
#
# True Positives (TP): 44
# False Negatives (FN): 0
# False Positives (FP): 163552
# True Negatives (TN): 0
# Selected SAT: citizen
# Number of segments in SAT: 98
#
# Building matrix…
# Similarity matrix dimensions: (98, 163596)
#
# True Positives (TP): 98
# False Negatives (FN): 0
# False Positives (FP): 163498
# True Negatives (TN): 0
# Selected SAT: mun
# Number of segments in SAT: 235
#
# Building matrix…
# Similarity matrix dimensions: (235, 163596)
#
# True Positives (TP): 235
# False Negatives (FN): 0
# False Positives (FP): 163361
# True Negatives (TN): 0
# Selected SAT: district
# Number of segments in SAT: 90
#
# Building matrix…
# Similarity matrix dimensions: (90, 163596)
#
# True Positives (TP): 90
# False Negatives (FN): 0
# False Positives (FP): 163506
# True Negatives (TN): 0
# Selected SAT: exsess
# Number of segments in SAT: 163
#
# Building matrix…
# Similarity matrix dimensions: (163, 163596)
#
# True Positives (TP): 163
# False Negatives (FN): 0
# False Positives (FP): 163433
# True Negatives (TN): 0
# Selected SAT: war
# Number of segments in SAT: 145
#
# Building matrix…
# Similarity matrix dimensions: (145, 163596)
#
# True Positives (TP): 145
# False Negatives (FN): 0
# False Positives (FP): 163451
# True Negatives (TN): 0
# Selected SAT: judcrts1
# Number of segments in SAT: 64
#
# Building matrix…
# Similarity matrix dimensions: (64, 163596)
#
# True Positives (TP): 64
# False Negatives (FN): 0
# False Positives (FP): 163529
# True Negatives (TN): 3
# Selected SAT: pubtri
# Number of segments in SAT: 118
#
# Building matrix…
# Similarity matrix dimensions: (118, 163596)
#
# True Positives (TP): 118
# False Negatives (FN): 0
# False Positives (FP): 163478
# True Negatives (TN): 0
# Selected SAT: hosdiss
# Number of segments in SAT: 139
#
# Building matrix…
# Similarity matrix dimensions: (139, 163596)
#
# True Positives (TP): 139
# False Negatives (FN): 0
# False Positives (FP): 163457
# True Negatives (TN): 0
# Selected SAT: uncon
# Number of segments in SAT: 243
#
# Building matrix…
# Similarity matrix dimensions: (243, 163596)
#
# True Positives (TP): 243
# False Negatives (FN): 0
# False Positives (FP): 163353
# True Negatives (TN): 0
# Selected SAT: solid
# Number of segments in SAT: 179
#
# Building matrix…
# Similarity matrix dimensions: (179, 163596)
#
# True Positives (TP): 179
# False Negatives (FN): 0
# False Positives (FP): 163417
# True Negatives (TN): 0
# Selected SAT: ethincl
# Number of segments in SAT: 53
#
# Building matrix…
# Similarity matrix dimensions: (53, 163596)
#
# True Positives (TP): 53
# False Negatives (FN): 0
# False Positives (FP): 163543
# True Negatives (TN): 0
# Selected SAT: intorgs
# Number of segments in SAT: 290
#
# Building matrix…
# Similarity matrix dimensions: (290, 163596)
#
# True Positives (TP): 290
# False Negatives (FN): 0
# False Positives (FP): 163306
# True Negatives (TN): 0
# Selected SAT: overthrw
# Number of segments in SAT: 7
#
# Building matrix…
# Similarity matrix dimensions: (7, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 7
# False Positives (FP): 159174
# True Negatives (TN): 4415
# Selected SAT: system
# Number of segments in SAT: 95
#
# Building matrix…
# Similarity matrix dimensions: (95, 163596)
#
# True Positives (TP): 91
# False Negatives (FN): 4
# False Positives (FP): 163500
# True Negatives (TN): 1
# Selected SAT: voteres
# Number of segments in SAT: 123
#
# Building matrix…
# Similarity matrix dimensions: (123, 163596)
#
# True Positives (TP): 123
# False Negatives (FN): 0
# False Positives (FP): 163473
# True Negatives (TN): 0
# Selected SAT: motto
# Number of segments in SAT: 32
#
# Building matrix…
# Similarity matrix dimensions: (32, 163596)
#
# True Positives (TP): 32
# False Negatives (FN): 0
# False Positives (FP): 163564
# True Negatives (TN): 0
# Selected SAT: capital
# Number of segments in SAT: 44
#
# Building matrix…
# Similarity matrix dimensions: (44, 163596)
#
# True Positives (TP): 39
# False Negatives (FN): 5
# False Positives (FP): 163537
# True Negatives (TN): 15
# Selected SAT: privacy
# Number of segments in SAT: 101
#
# Building matrix…
# Similarity matrix dimensions: (101, 163596)
#
# True Positives (TP): 101
# False Negatives (FN): 0
# False Positives (FP): 163495
# True Negatives (TN): 0
# Selected SAT: civil
# Number of segments in SAT: 76
#
# Building matrix…
# Similarity matrix dimensions: (76, 163596)
#
# True Positives (TP): 76
# False Negatives (FN): 0
# False Positives (FP): 163520
# True Negatives (TN): 0
# Selected SAT: provwork
# Number of segments in SAT: 110
#
# Building matrix…
# Similarity matrix dimensions: (110, 163596)
#
# True Positives (TP): 110
# False Negatives (FN): 0
# False Positives (FP): 163486
# True Negatives (TN): 0
# Selected SAT: remuner
# Number of segments in SAT: 82
#
# Building matrix…
# Similarity matrix dimensions: (82, 163596)
#
# True Positives (TP): 79
# False Negatives (FN): 3
# False Positives (FP): 163511
# True Negatives (TN): 3
# Selected SAT: asylum
# Number of segments in SAT: 47
#
# Building matrix…
# Similarity matrix dimensions: (47, 163596)
#
# True Positives (TP): 47
# False Negatives (FN): 0
# False Positives (FP): 163549
# True Negatives (TN): 0
# Selected SAT: excrim
# Number of segments in SAT: 103
#
# Building matrix…
# Similarity matrix dimensions: (103, 163596)
#
# True Positives (TP): 82
# False Negatives (FN): 21
# False Positives (FP): 163487
# True Negatives (TN): 6
# Selected SAT: hosage
# Number of segments in SAT: 122
#
# Building matrix…
# Similarity matrix dimensions: (122, 163596)
#
# True Positives (TP): 122
# False Negatives (FN): 0
# False Positives (FP): 163474
# True Negatives (TN): 0
# Selected SAT: hr
# Number of segments in SAT: 49
#
# Building matrix…
# Similarity matrix dimensions: (49, 163596)
#
# True Positives (TP): 49
# False Negatives (FN): 0
# False Positives (FP): 163547
# True Negatives (TN): 0
# Selected SAT: cabsel
# Number of segments in SAT: 196
#
# Building matrix…
# Similarity matrix dimensions: (196, 163596)
#
# True Positives (TP): 196
# False Negatives (FN): 0
# False Positives (FP): 163400
# True Negatives (TN): 0
# Selected SAT: lhlead
# Number of segments in SAT: 99
#
# Building matrix…
# Similarity matrix dimensions: (99, 163596)
#
# True Positives (TP): 97
# False Negatives (FN): 2
# False Positives (FP): 163489
# True Negatives (TN): 8
# Selected SAT: pubmin
# Number of segments in SAT: 27
#
# Building matrix…
# Similarity matrix dimensions: (27, 163596)
#
# True Positives (TP): 19
# False Negatives (FN): 8
# False Positives (FP): 163545
# True Negatives (TN): 24
# Selected SAT: childpro
# Number of segments in SAT: 110
#
# Building matrix…
# Similarity matrix dimensions: (110, 163596)
#
# True Positives (TP): 110
# False Negatives (FN): 0
# False Positives (FP): 163486
# True Negatives (TN): 0
# Selected SAT: artists
# Number of segments in SAT: 156
#
# Building matrix…
# Similarity matrix dimensions: (156, 163596)
#
# True Positives (TP): 156
# False Negatives (FN): 0
# False Positives (FP): 163440
# True Negatives (TN): 0
# Selected SAT: telecom
# Number of segments in SAT: 189
#
# Building matrix…
# Similarity matrix dimensions: (189, 163596)
#
# True Positives (TP): 189
# False Negatives (FN): 0
# False Positives (FP): 163407
# True Negatives (TN): 0
# Selected SAT: suppow
# Number of segments in SAT: 96
#
# Building matrix…
# Similarity matrix dimensions: (96, 163596)
#
# True Positives (TP): 96
# False Negatives (FN): 0
# False Positives (FP): 163500
# True Negatives (TN): 0
# Selected SAT: levjud
# Number of segments in SAT: 136
#
# Building matrix…
# Similarity matrix dimensions: (136, 163596)
#
# True Positives (TP): 136
# False Negatives (FN): 0
# False Positives (FP): 163460
# True Negatives (TN): 0
# Selected SAT: judcrts4
# Number of segments in SAT: 91
#
# Building matrix…
# Similarity matrix dimensions: (91, 163596)
#
# True Positives (TP): 91
# False Negatives (FN): 0
# False Positives (FP): 163505
# True Negatives (TN): 0
# Selected SAT: illsub
# Number of segments in SAT: 74
#
# Building matrix…
# Similarity matrix dimensions: (74, 163596)
#
# True Positives (TP): 74
# False Negatives (FN): 0
# False Positives (FP): 163522
# True Negatives (TN): 0
# Selected SAT: hocterm
# Number of segments in SAT: 80
#
# Building matrix…
# Similarity matrix dimensions: (80, 163596)
#
# True Positives (TP): 72
# False Negatives (FN): 8
# False Positives (FP): 163347
# True Negatives (TN): 169
# Selected SAT: camppubf
# Number of segments in SAT: 60
#
# Building matrix…
# Similarity matrix dimensions: (60, 163596)
#
# True Positives (TP): 60
# False Negatives (FN): 0
# False Positives (FP): 163536
# True Negatives (TN): 0
# Selected SAT: access
# Number of segments in SAT: 43
#
# Building matrix…
# Similarity matrix dimensions: (43, 163596)
#
# True Positives (TP): 43
# False Negatives (FN): 0
# False Positives (FP): 163553
# True Negatives (TN): 0
# Selected SAT: equal
# Number of segments in SAT: 111
#
# Building matrix…
# Similarity matrix dimensions: (111, 163596)
#
# True Positives (TP): 111
# False Negatives (FN): 0
# False Positives (FP): 163485
# True Negatives (TN): 0
# Selected SAT: judind
# Number of segments in SAT: 166
#
# Building matrix…
# Similarity matrix dimensions: (166, 163596)
#
# True Positives (TP): 161
# False Negatives (FN): 5
# False Positives (FP): 163424
# True Negatives (TN): 6
# Selected SAT: judcrts2
# Number of segments in SAT: 24
#
# Building matrix…
# Similarity matrix dimensions: (24, 163596)
#
# True Positives (TP): 16
# False Negatives (FN): 8
# False Positives (FP): 161473
# True Negatives (TN): 2099
# Selected SAT: interp
# Number of segments in SAT: 202
#
# Building matrix…
# Similarity matrix dimensions: (202, 163596)
#
# True Positives (TP): 202
# False Negatives (FN): 0
# False Positives (FP): 163394
# True Negatives (TN): 0
# Selected SAT: bank
# Number of segments in SAT: 91
#
# Building matrix…
# Similarity matrix dimensions: (91, 163596)
#
# True Positives (TP): 91
# False Negatives (FN): 0
# False Positives (FP): 163505
# True Negatives (TN): 0
# Selected SAT: inalrght
# Number of segments in SAT: 110
#
# Building matrix…
# Similarity matrix dimensions: (110, 163596)
#
# True Positives (TP): 110
# False Negatives (FN): 0
# False Positives (FP): 163486
# True Negatives (TN): 0
# Selected SAT: equalgr7
# Number of segments in SAT: 9
#
# Building matrix…
# Similarity matrix dimensions: (9, 163596)
#
# True Positives (TP): 2
# False Negatives (FN): 7
# False Positives (FP): 163517
# True Negatives (TN): 70
# Selected SAT: cappun
# Number of segments in SAT: 51
#
# Building matrix…
# Similarity matrix dimensions: (51, 163596)
# True Positives (TP): 40
# False Negatives (FN): 11
# False Positives (FP): 163495
# True Negatives (TN): 50
# Selected SAT: prerel
# Number of segments in SAT: 62
#
# Building matrix…
# Similarity matrix dimensions: (62, 163596)
#
# True Positives (TP): 55
# False Negatives (FN): 7
# False Positives (FP): 163508
# True Negatives (TN): 26
# Selected SAT: speedtri
# Number of segments in SAT: 118
#
# Building matrix…
# Similarity matrix dimensions: (118, 163596)
#
# True Positives (TP): 118
# False Negatives (FN): 0
# False Positives (FP): 163478
# True Negatives (TN): 0
# Selected SAT: falseimp
# Number of segments in SAT: 76
#
# Building matrix…
# Similarity matrix dimensions: (76, 163596)
#
# True Positives (TP): 71
# False Negatives (FN): 5
# False Positives (FP): 163504
# True Negatives (TN): 16
# Selected SAT: examwit
# Number of segments in SAT: 66
#
# Building matrix…
# Similarity matrix dimensions: (66, 163596)
#
# True Positives (TP): 63
# False Negatives (FN): 3
# False Positives (FP): 163521
# True Negatives (TN): 9
# Selected SAT: juvenile
# Number of segments in SAT: 66
#
# Building matrix…
# Similarity matrix dimensions: (66, 163596)
#
# True Positives (TP): 66
# False Negatives (FN): 0
# False Positives (FP): 163530
# True Negatives (TN): 0
# Selected SAT: fndfam
# Number of segments in SAT: 74
#
# Building matrix…
# Similarity matrix dimensions: (74, 163596)
#
# True Positives (TP): 74
# False Negatives (FN): 0
# False Positives (FP): 163522
# True Negatives (TN): 0
# Selected SAT: marriage
# Number of segments in SAT: 46
#
# Building matrix…
# Similarity matrix dimensions: (46, 163596)
#
# True Positives (TP): 31
# False Negatives (FN): 15
# False Positives (FP): 163510
# True Negatives (TN): 40
# Selected SAT: libel
# Number of segments in SAT: 73
#
# Building matrix…
# Similarity matrix dimensions: (73, 163596)
#
# True Positives (TP): 73
# False Negatives (FN): 0
# False Positives (FP): 163523
# True Negatives (TN): 0
# Selected SAT: jointrde
# Number of segments in SAT: 99
#
# Building matrix…
# Similarity matrix dimensions: (99, 163596)
#
# True Positives (TP): 95
# False Negatives (FN): 4
# False Positives (FP): 163494
# True Negatives (TN): 3
# Selected SAT: proprght
# Number of segments in SAT: 99
#
# Building matrix…
# Similarity matrix dimensions: (99, 163596)
#
# True Positives (TP): 75
# False Negatives (FN): 24
# False Positives (FP): 163394
# True Negatives (TN): 103
# Selected SAT: exprop
# Number of segments in SAT: 171
#
# Building matrix…
# Similarity matrix dimensions: (171, 163596)
#
# True Positives (TP): 171
# False Negatives (FN): 0
# False Positives (FP): 163425
# True Negatives (TN): 0
# Selected SAT: intprop
# Number of segments in SAT: 93
#
# Building matrix…
# Similarity matrix dimensions: (93, 163596)
#
# True Positives (TP): 93
# False Negatives (FN): 0
# False Positives (FP): 163503
# True Negatives (TN): 0
# Selected SAT: acfree
# Number of segments in SAT: 58
#
# Building matrix…
# Similarity matrix dimensions: (58, 163596)
#
# True Positives (TP): 58
# False Negatives (FN): 0
# False Positives (FP): 163538
# True Negatives (TN): 0
# Selected SAT: occupate
# Number of segments in SAT: 86
#
# Building matrix…
# Similarity matrix dimensions: (86, 163596)
#
# True Positives (TP): 77
# False Negatives (FN): 9
# False Positives (FP): 163505
# True Negatives (TN): 5
# Selected SAT: childwrk
# Number of segments in SAT: 89
#
# Building matrix…
# Similarity matrix dimensions: (89, 163596)
#
# True Positives (TP): 89
# False Negatives (FN): 0
# False Positives (FP): 163507
# True Negatives (TN): 0
# Selected SAT: health
# Number of segments in SAT: 83
#
# Building matrix…
# Similarity matrix dimensions: (83, 163596)
#
# True Positives (TP): 83
# False Negatives (FN): 0
# False Positives (FP): 163513
# True Negatives (TN): 0
# Selected SAT: tv
# Number of segments in SAT: 124
#
# Building matrix…
# Similarity matrix dimensions: (124, 163596)
#
# True Positives (TP): 124
# False Negatives (FN): 0
# False Positives (FP): 163472
# True Negatives (TN): 0
# Selected SAT: amend
# Number of segments in SAT: 96
#
# Building matrix…
# Similarity matrix dimensions: (96, 163596)
#
# True Positives (TP): 96
# False Negatives (FN): 0
# False Positives (FP): 163500
# True Negatives (TN): 0
# Selected SAT: treat
# Number of segments in SAT: 295
#
# Building matrix…
# Similarity matrix dimensions: (295, 163596)
#
# True Positives (TP): 295
# False Negatives (FN): 0
# False Positives (FP): 163301
# True Negatives (TN): 0
# Selected SAT: budget
# Number of segments in SAT: 202
#
# Building matrix…
# Similarity matrix dimensions: (202, 163596)
#
# True Positives (TP): 202
# False Negatives (FN): 0
# False Positives (FP): 163394
# True Negatives (TN): 0
# Selected SAT: invexe
# Number of segments in SAT: 207
#
# Building matrix…
# Similarity matrix dimensions: (207, 163596)
#
# True Positives (TP): 207
# False Negatives (FN): 0
# False Positives (FP): 163389
# True Negatives (TN): 0
# Selected SAT: consel
# Number of segments in SAT: 97
#
# Building matrix…
# Similarity matrix dimensions: (97, 163596)
#
# True Positives (TP): 78
# False Negatives (FN): 19
# False Positives (FP): 163352
# True Negatives (TN): 147
# Selected SAT: attend
# Number of segments in SAT: 75
#
# Building matrix…
# Similarity matrix dimensions: (75, 163596)
#
# True Positives (TP): 75
# False Negatives (FN): 0
# False Positives (FP): 163517
# True Negatives (TN): 4
# Selected SAT: lhage
# Number of segments in SAT: 119
#
# Building matrix…
# Similarity matrix dimensions: (119, 163596)
#
# True Positives (TP): 119
# False Negatives (FN): 0
# False Positives (FP): 163477
# True Negatives (TN): 0
# Selected SAT: override
# Number of segments in SAT: 83
#
# Building matrix…
# Similarity matrix dimensions: (83, 163596)
#
# True Positives (TP): 83
# False Negatives (FN): 0
# False Positives (FP): 163512
# True Negatives (TN): 1
# Selected SAT: hosdec
# Number of segments in SAT: 131
#
# Building matrix…
# Similarity matrix dimensions: (131, 163596)
#
# True Positives (TP): 131
# False Negatives (FN): 0
# False Positives (FP): 163465
# True Negatives (TN): 0
# Selected SAT: legapp
# Number of segments in SAT: 113
#
# Building matrix…
# Similarity matrix dimensions: (113, 163596)
#
# True Positives (TP): 113
# False Negatives (FN): 0
# False Positives (FP): 163483
# True Negatives (TN): 0
# Selected SAT: hocsel
# Number of segments in SAT: 236
#
# Building matrix…
# Similarity matrix dimensions: (236, 163596)
#
# True Positives (TP): 236
# False Negatives (FN): 0
# False Positives (FP): 163359
# True Negatives (TN): 1
# Selected SAT: ordsel
# Number of segments in SAT: 216
#
# Building matrix…
# Similarity matrix dimensions: (216, 163596)
#
# True Positives (TP): 216
# False Negatives (FN): 0
# False Positives (FP): 163380
# True Negatives (TN): 0
# Selected SAT: atgen
# Number of segments in SAT: 170
#
# Building matrix…
# Similarity matrix dimensions: (170, 163596)
#
# True Positives (TP): 170
# False Negatives (FN): 0
# False Positives (FP): 163426
# True Negatives (TN): 0
# Selected SAT: milcom
# Number of segments in SAT: 111
#
# Building matrix…
# Similarity matrix dimensions: (111, 163596)
#
# True Positives (TP): 109
# False Negatives (FN): 2
# False Positives (FP): 163485
# True Negatives (TN): 0
# Selected SAT: ecom
# Number of segments in SAT: 173
#
# Building matrix…
# Similarity matrix dimensions: (173, 163596)
#
# True Positives (TP): 173
# False Negatives (FN): 0
# False Positives (FP): 163423
# True Negatives (TN): 0
# Selected SAT: hosimm
# Number of segments in SAT: 63
#
# Building matrix…
# Similarity matrix dimensions: (63, 163596)
#
# True Positives (TP): 63
# False Negatives (FN): 0
# False Positives (FP): 163530
# True Negatives (TN): 3
# Selected SAT: depexec
# Number of segments in SAT: 116
#
# Building matrix…
# Similarity matrix dimensions: (116, 163596)
#
# True Positives (TP): 116
# False Negatives (FN): 0
# False Positives (FP): 163480
# True Negatives (TN): 0
# Selected SAT: hogsucc
# Number of segments in SAT: 68
#
# Building matrix…
# Similarity matrix dimensions: (68, 163596)
#
# True Positives (TP): 65
# False Negatives (FN): 3
# False Positives (FP): 163390
# True Negatives (TN): 138
# Selected SAT: hogdlim
# Number of segments in SAT: 26
#
# Building matrix…
# Similarity matrix dimensions: (26, 163596)
#
# True Positives (TP): 13
# False Negatives (FN): 13
# False Positives (FP): 163036
# True Negatives (TN): 534
# Selected SAT: hocres
# Number of segments in SAT: 110
#
# Building matrix…
# Similarity matrix dimensions: (110, 163596)
#
# True Positives (TP): 110
# False Negatives (FN): 0
# False Positives (FP): 163486
# True Negatives (TN): 0
# Selected SAT: ordres
# Number of segments in SAT: 98
#
# Building matrix…
# Similarity matrix dimensions: (98, 163596)
#
# True Positives (TP): 98
# False Negatives (FN): 0
# False Positives (FP): 163498
# True Negatives (TN): 0
# Selected SAT: jrem
# Number of segments in SAT: 264
#
# Building matrix…
# Similarity matrix dimensions: (264, 163596)
#
# True Positives (TP): 264
# False Negatives (FN): 0
# False Positives (FP): 163332
# True Negatives (TN): 0
# Selected SAT: ombuds
# Number of segments in SAT: 77
#
# Building matrix…
# Similarity matrix dimensions: (77, 163596)
#
# True Positives (TP): 77
# False Negatives (FN): 0
# False Positives (FP): 163519
# True Negatives (TN): 0
# Selected SAT: hogdec
# Number of segments in SAT: 47
#
# Building matrix…
# Similarity matrix dimensions: (47, 163596)
#
# True Positives (TP): 47
# False Negatives (FN): 0
# False Positives (FP): 163549
# True Negatives (TN): 0
# Selected SAT: unamend
# Number of segments in SAT: 34
#
# Building matrix…
# Similarity matrix dimensions: (34, 163596)
#
# True Positives (TP): 34
# False Negatives (FN): 0
# False Positives (FP): 163559
# True Negatives (TN): 3
# Selected SAT: concop
# Number of segments in SAT: 6
#
# Building matrix…
# Similarity matrix dimensions: (6, 163596)
#
# True Positives (TP): 4
# False Negatives (FN): 2
# False Positives (FP): 163020
# True Negatives (TN): 570
# Selected SAT: conright
# Number of segments in SAT: 30
#
# Building matrix…
# Similarity matrix dimensions: (30, 163596)
#
# True Positives (TP): 29
# False Negatives (FN): 1
# False Positives (FP): 163559
# True Negatives (TN): 7
# Selected SAT: taxes
# Number of segments in SAT: 42
#
# Building matrix…
# Similarity matrix dimensions: (42, 163596)
#
# True Positives (TP): 39
# False Negatives (FN): 3
# False Positives (FP): 163546
# True Negatives (TN): 8
# Selected SAT: resrce
# Number of segments in SAT: 118
#
# Building matrix…
# Similarity matrix dimensions: (118, 163596)
#
# True Positives (TP): 118
# False Negatives (FN): 0
# False Positives (FP): 163478
# True Negatives (TN): 0
# Selected SAT: prevcond
# Number of segments in SAT: 118
#
# Building matrix…
# Similarity matrix dimensions: (118, 163596)
#
# True Positives (TP): 118
# False Negatives (FN): 0
# False Positives (FP): 163478
# True Negatives (TN): 0
# Selected SAT: lang
# Number of segments in SAT: 73
#
# Building matrix…
# Similarity matrix dimensions: (73, 163596)
#
# True Positives (TP): 73
# False Negatives (FN): 0
# False Positives (FP): 163523
# True Negatives (TN): 0
# Selected SAT: offrel
# Number of segments in SAT: 52
#
# Building matrix…
# Similarity matrix dimensions: (52, 163596)
#
# True Positives (TP): 51
# False Negatives (FN): 1
# False Positives (FP): 163534
# True Negatives (TN): 10
# Selected SAT: natcit
# Number of segments in SAT: 120
#
# Building matrix…
# Similarity matrix dimensions: (120, 163596)
#
# True Positives (TP): 120
# False Negatives (FN): 0
# False Positives (FP): 163476
# True Negatives (TN): 0
# Selected SAT: citren
# Number of segments in SAT: 55
#
# Building matrix…
# Similarity matrix dimensions: (55, 163596)
#
# True Positives (TP): 55
# False Negatives (FN): 0
# False Positives (FP): 163514
# True Negatives (TN): 27
# Selected SAT: citrev
# Number of segments in SAT: 94
#
# Building matrix…
# Similarity matrix dimensions: (94, 163596)
#
# True Positives (TP): 94
# False Negatives (FN): 0
# False Positives (FP): 163502
# True Negatives (TN): 0
# Selected SAT: binding
# Number of segments in SAT: 36
#
# Building matrix…
# Similarity matrix dimensions: (36, 163596)
#
# True Positives (TP): 36
# False Negatives (FN): 0
# False Positives (FP): 163560
# True Negatives (TN): 0
# Selected SAT: debtors
# Number of segments in SAT: 28
#
# Building matrix…
# Similarity matrix dimensions: (28, 163596)
#
# True Positives (TP): 28
# False Negatives (FN): 0
# False Positives (FP): 163568
# True Negatives (TN): 0
# Selected SAT: habcorp
# Number of segments in SAT: 152
#
# Building matrix…
# Similarity matrix dimensions: (152, 163596)
#
# True Positives (TP): 152
# False Negatives (FN): 0
# False Positives (FP): 163444
# True Negatives (TN): 0
# Selected SAT: expost
# Number of segments in SAT: 140
#
# Building matrix…
# Similarity matrix dimensions: (140, 163596)
#
# True Positives (TP): 114
# False Negatives (FN): 26
# False Positives (FP): 163364
# True Negatives (TN): 92
# Selected SAT: wolaw
# Number of segments in SAT: 148
#
# Building matrix…
# Similarity matrix dimensions: (148, 163596)
#
# True Positives (TP): 147
# False Negatives (FN): 1
# False Positives (FP): 163442
# True Negatives (TN): 6
# Selected SAT: doubjep
# Number of segments in SAT: 89
#
# Building matrix…
# Similarity matrix dimensions: (89, 163596)
#
# True Positives (TP): 52
# False Negatives (FN): 37
# False Positives (FP): 163484
# True Negatives (TN): 23
# Selected SAT: safework
# Number of segments in SAT: 76
#
# Building matrix…
# Similarity matrix dimensions: (76, 163596)
#
# True Positives (TP): 75
# False Negatives (FN): 1
# False Positives (FP): 163520
# True Negatives (TN): 0
# Selected SAT: partrght
# Number of segments in SAT: 80
#
# Building matrix…
# Similarity matrix dimensions: (80, 163596)
#
# True Positives (TP): 62
# False Negatives (FN): 18
# False Positives (FP): 163461
# True Negatives (TN): 55
# Selected SAT: partreg
# Number of segments in SAT: 105
#
# Building matrix…
# Similarity matrix dimensions: (105, 163596)
#
# True Positives (TP): 105
# False Negatives (FN): 0
# False Positives (FP): 163491
# True Negatives (TN): 0
# Selected SAT: equalgr8
# Number of segments in SAT: 20
#
# Building matrix…
# Similarity matrix dimensions: (20, 163596)
#
# True Positives (TP): 20
# False Negatives (FN): 0
# False Positives (FP): 163576
# True Negatives (TN): 0
# Selected SAT: achighed
# Number of segments in SAT: 60
#
# Building matrix…
# Similarity matrix dimensions: (60, 163596)
#
# True Positives (TP): 60
# False Negatives (FN): 0
# False Positives (FP): 163536
# True Negatives (TN): 0
# Selected SAT: spend
# Number of segments in SAT: 73
#
# Building matrix…
# Similarity matrix dimensions: (73, 163596)
#
# True Positives (TP): 73
# False Negatives (FN): 0
# False Positives (FP): 163523
# True Negatives (TN): 0
# Selected SAT: finance
# Number of segments in SAT: 66
#
# Building matrix…
# Similarity matrix dimensions: (66, 163596)
#
# True Positives (TP): 66
# False Negatives (FN): 0
# False Positives (FP): 163530
# True Negatives (TN): 0
# Selected SAT: tax
# Number of segments in SAT: 93
#
# Building matrix…
# Similarity matrix dimensions: (93, 163596)
#
# True Positives (TP): 93
# False Negatives (FN): 0
# False Positives (FP): 163503
# True Negatives (TN): 0
# Selected SAT: census
# Number of segments in SAT: 76
#
# Building matrix…
# Similarity matrix dimensions: (76, 163596)
#
# True Positives (TP): 76
# False Negatives (FN): 0
# False Positives (FP): 163520
# True Negatives (TN): 0
# Selected SAT: hogpow
# Number of segments in SAT: 81
#
# Building matrix…
# Similarity matrix dimensions: (81, 163596)
#
# True Positives (TP): 81
# False Negatives (FN): 0
# False Positives (FP): 163515
# True Negatives (TN): 0
# Selected SAT: judsal
# Number of segments in SAT: 81
#
# Building matrix…
# Similarity matrix dimensions: (81, 163596)
#
# True Positives (TP): 81
# False Negatives (FN): 0
# False Positives (FP): 163515
# True Negatives (TN): 0
# ...
#
# True Positives (TP): 6
# False Negatives (FN): 8
# False Positives (FP): 163197
# True Negatives (TN): 385
# Selected SAT: finsup4
# Number of segments in SAT: 105
#
# Building matrix…
# Similarity matrix dimensions: (105, 163596)
#
# True Positives (TP): 105
# False Negatives (FN): 0
# False Positives (FP): 163491
# True Negatives (TN): 0
# Selected SAT: work
# Number of segments in SAT: 40
#
# Building matrix…
# Similarity matrix dimensions: (40, 163596)
#
# True Positives (TP): 40
# False Negatives (FN): 0
# False Positives (FP): 163556
# True Negatives (TN): 0
# Selected SAT: hospow
# Number of segments in SAT: 236
#
# Building matrix…
# Similarity matrix dimensions: (236, 163596)
#
# True Positives (TP): 236
# False Negatives (FN): 0
# False Positives (FP): 163360
# True Negatives (TN): 0
# Selected SAT: terror
# Number of segments in SAT: 39
#
# Building matrix…
# Similarity matrix dimensions: (39, 163596)
#
# True Positives (TP): 39
# False Negatives (FN): 0
# False Positives (FP): 163557
# True Negatives (TN): 0
# Selected SAT: ecpow
# Number of segments in SAT: 18
#
# Building matrix…
# Similarity matrix dimensions: (18, 163596)
#
# True Positives (TP): 7
# False Negatives (FN): 11
# False Positives (FP): 162607
# True Negatives (TN): 971
# Selected SAT: ecres
# Number of segments in SAT: 12
#
# Building matrix…
# Similarity matrix dimensions: (12, 163596)
#
# True Positives (TP): 9
# False Negatives (FN): 3
# False Positives (FP): 162248
# True Negatives (TN): 1336
# Selected SAT: ecsel
# Number of segments in SAT: 14
#
# Building matrix…
# Similarity matrix dimensions: (14, 163596)
#
# True Positives (TP): 11
# False Negatives (FN): 3
# False Positives (FP): 162898
# True Negatives (TN): 684
# Selected SAT: session
# Number of segments in SAT: 61
#
# Building matrix…
# Similarity matrix dimensions: (61, 163596)
#
# True Positives (TP): 59
# False Negatives (FN): 2
# False Positives (FP): 163530
# True Negatives (TN): 5
# Selected SAT: medcom
# Number of segments in SAT: 16
#
# Building matrix…
# Similarity matrix dimensions: (16, 163596)
#
# True Positives (TP): 16
# False Negatives (FN): 0
# False Positives (FP): 163580
# True Negatives (TN): 0
# Selected SAT: govmed
# Number of segments in SAT: 54
#
# Building matrix…
# Similarity matrix dimensions: (54, 163596)
#
# True Positives (TP): 54
# False Negatives (FN): 0
# False Positives (FP): 163542
# True Negatives (TN): 0
# Selected SAT: hocop
# Number of segments in SAT: 16
#
# Building matrix…
# Similarity matrix dimensions: (16, 163596)
#
# True Positives (TP): 13
# False Negatives (FN): 3
# False Positives (FP): 163085
# True Negatives (TN): 495
# Selected SAT: conage
# Number of segments in SAT: 23
#
# Building matrix…
# Similarity matrix dimensions: (23, 163596)
#
# True Positives (TP): 22
# False Negatives (FN): 1
# False Positives (FP): 163469
# True Negatives (TN): 104
# Selected SAT: adsel
# Number of segments in SAT: 28
#
# Building matrix…
# Similarity matrix dimensions: (28, 163596)
#
# True Positives (TP): 27
# False Negatives (FN): 1
# False Positives (FP): 163520
# True Negatives (TN): 48
# Selected SAT: adres
# Number of segments in SAT: 15
#
# Building matrix…
# Similarity matrix dimensions: (15, 163596)
#
# True Positives (TP): 13
# False Negatives (FN): 2
# False Positives (FP): 163019
# True Negatives (TN): 562
# Selected SAT: strike
# Number of segments in SAT: 56
#
# Building matrix…
# Similarity matrix dimensions: (56, 163596)
#
# True Positives (TP): 56
# False Negatives (FN): 0
# False Positives (FP): 163540
# True Negatives (TN): 0
# Selected SAT: dueproc
# Number of segments in SAT: 38
#
# Building matrix…
# Similarity matrix dimensions: (38, 163596)
#
# True Positives (TP): 36
# False Negatives (FN): 2
# False Positives (FP): 163543
# True Negatives (TN): 15
# Selected SAT: housenum
# Number of segments in SAT: 67
#
# Building matrix…
# Similarity matrix dimensions: (67, 163596)
#
# True Positives (TP): 65
# False Negatives (FN): 2
# False Positives (FP): 163520
# True Negatives (TN): 9
# Selected SAT: uhlead
# Number of segments in SAT: 44
#
# Building matrix…
# Similarity matrix dimensions: (44, 163596)
#
# True Positives (TP): 42
# False Negatives (FN): 2
# False Positives (FP): 163522
# True Negatives (TN): 30
# Selected SAT: recvote
# Number of segments in SAT: 11
#
# Building matrix…
# Similarity matrix dimensions: (11, 163596)
#
# True Positives (TP): 2
# False Negatives (FN): 9
# False Positives (FP): 158078
# True Negatives (TN): 5507
# Selected SAT: divhouse
# Number of segments in SAT: 26
#
# Building matrix…
# Similarity matrix dimensions: (26, 163596)
#
# True Positives (TP): 26
# False Negatives (FN): 0
# False Positives (FP): 163543
# True Negatives (TN): 27
# Selected SAT: reltax
# Number of segments in SAT: 5
#
# Building matrix…
# Similarity matrix dimensions: (5, 163596)
#
# True Positives (TP): 2
# False Negatives (FN): 3
# False Positives (FP): 163056
# True Negatives (TN): 535
# Selected SAT: rellaw
# Number of segments in SAT: 21
#
# Building matrix…
# Similarity matrix dimensions: (21, 163596)
#
# True Positives (TP): 17
# False Negatives (FN): 4
# False Positives (FP): 163469
# True Negatives (TN): 106
# Selected SAT: rightres
# Number of segments in SAT: 27
#
# Building matrix…
# Similarity matrix dimensions: (27, 163596)
#
# True Positives (TP): 27
# False Negatives (FN): 0
# False Positives (FP): 163569
# True Negatives (TN): 0
# Selected SAT: uhquota
# Number of segments in SAT: 26
#
# Building matrix…
# Similarity matrix dimensions: (26, 163596)
#
# True Positives (TP): 26
# False Negatives (FN): 0
# False Positives (FP): 163570
# True Negatives (TN): 0
# Selected SAT: uhage
# Number of segments in SAT: 48
#
# Building matrix…
# Similarity matrix dimensions: (48, 163596)
#
# True Positives (TP): 48
# False Negatives (FN): 0
# False Positives (FP): 163531
# True Negatives (TN): 17
# Selected SAT: shelter
# Number of segments in SAT: 38
#
# Building matrix…
# Similarity matrix dimensions: (38, 163596)
#
# True Positives (TP): 38
# False Negatives (FN): 0
# False Positives (FP): 163558
# True Negatives (TN): 0
# Selected SAT: uhrest
# Number of segments in SAT: 68
#
# Building matrix…
# Similarity matrix dimensions: (68, 163596)
#
# True Positives (TP): 68
# False Negatives (FN): 0
# False Positives (FP): 163528
# True Negatives (TN): 0
# Selected SAT: lhspleg
# Number of segments in SAT: 58
#
# Building matrix…
# Similarity matrix dimensions: (58, 163596)
#
# True Positives (TP): 58
# False Negatives (FN): 0
# False Positives (FP): 163538
# True Negatives (TN): 0
# Selected SAT: uhselect
# Number of segments in SAT: 87
#
# Building matrix…
# Similarity matrix dimensions: (87, 163596)
#
# True Positives (TP): 87
# False Negatives (FN): 0
# False Positives (FP): 163509
# True Negatives (TN): 0
# Selected SAT: uhseats
# Number of segments in SAT: 59
#
# Building matrix…
# Similarity matrix dimensions: (59, 163596)
#
# True Positives (TP): 59
# False Negatives (FN): 0
# False Positives (FP): 163537
# True Negatives (TN): 0
# Selected SAT: legjoint
# Number of segments in SAT: 139
#
# Building matrix…
# Similarity matrix dimensions: (139, 163596)
#
# True Positives (TP): 139
# False Negatives (FN): 0
# False Positives (FP): 163457
# True Negatives (TN): 0
# Selected SAT: uhspleg
# Number of segments in SAT: 33
#
# Building matrix…
# Similarity matrix dimensions: (33, 163596)
#
# True Positives (TP): 33
# False Negatives (FN): 0
# False Positives (FP): 163563
# True Negatives (TN): 0
# Selected SAT: cabpow
# Number of segments in SAT: 131
#
# Building matrix…
# Similarity matrix dimensions: (131, 163596)
#
# True Positives (TP): 131
# False Negatives (FN): 0
# False Positives (FP): 163465
# True Negatives (TN): 0
# Selected SAT: judcrts7
# Number of segments in SAT: 23
#
# Building matrix…
# Similarity matrix dimensions: (23, 163596)
#
# True Positives (TP): 23
# False Negatives (FN): 0
# False Positives (FP): 163573
# True Negatives (TN): 0
# Selected SAT: judcrts8
# Number of segments in SAT: 20
#
# Building matrix…
# Similarity matrix dimensions: (20, 163596)
#
# True Positives (TP): 20
# False Negatives (FN): 0
# False Positives (FP): 163576
# True Negatives (TN): 0
# Selected SAT: cabinet
# Number of segments in SAT: 45
#
# Building matrix…
# Similarity matrix dimensions: (45, 163596)
#
# True Positives (TP): 44
# False Negatives (FN): 1
# False Positives (FP): 163517
# True Negatives (TN): 34
# Selected SAT: ecage
# Number of segments in SAT: 7
#
# Building matrix…
# Similarity matrix dimensions: (7, 163596)
#
# True Positives (TP): 7
# False Negatives (FN): 0
# False Positives (FP): 163428
# True Negatives (TN): 161
# Selected SAT: ecterm
# Number of segments in SAT: 8
#
# Building matrix…
# Similarity matrix dimensions: (8, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 8
# False Positives (FP): 151997
# True Negatives (TN): 11591
# Selected SAT: amparo
# Number of segments in SAT: 13
#
# Building matrix…
# Similarity matrix dimensions: (13, 163596)
#
# True Positives (TP): 13
# False Negatives (FN): 0
# False Positives (FP): 163580
# True Negatives (TN): 3
# Selected SAT: petition
# Number of segments in SAT: 35
#
# Building matrix…
# Similarity matrix dimensions: (35, 163596)
#
# True Positives (TP): 35
# False Negatives (FN): 0
# False Positives (FP): 163561
# True Negatives (TN): 0
# Selected SAT: scifree
# Number of segments in SAT: 16
#
# Building matrix…
# Similarity matrix dimensions: (16, 163596)
#
# True Positives (TP): 13
# False Negatives (FN): 3
# False Positives (FP): 163544
# True Negatives (TN): 36
# Selected SAT: hogimm
# Number of segments in SAT: 18
#
# Building matrix…
# Similarity matrix dimensions: (18, 163596)
#
# True Positives (TP): 16
# False Negatives (FN): 2
# False Positives (FP): 163325
# True Negatives (TN): 253
# Selected SAT: motive
# Number of segments in SAT: 82
#
# Building matrix…
# Similarity matrix dimensions: (82, 163596)
#
# True Positives (TP): 82
# False Negatives (FN): 0
# False Positives (FP): 163514
# True Negatives (TN): 0
# Selected SAT: partprf
# Number of segments in SAT: 1
#
# Building matrix…
# Similarity matrix dimensions: (1, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 1
# False Positives (FP): 156792
# True Negatives (TN): 6803
# Selected SAT: hogterml
# Number of segments in SAT: 9
#
# Building matrix…
# Similarity matrix dimensions: (9, 163596)
#
# True Positives (TP): 4
# False Negatives (FN): 5
# False Positives (FP): 160271
# True Negatives (TN): 3316
# Selected SAT: prevlead
# Number of segments in SAT: 8
#
# Building matrix…
# Similarity matrix dimensions: (8, 163596)
#
# True Positives (TP): 8
# False Negatives (FN): 0
# False Positives (FP): 163585
# True Negatives (TN): 3
# Selected SAT: assets
# Number of segments in SAT: 24
#
# Building matrix…
# Similarity matrix dimensions: (24, 163596)
#
# True Positives (TP): 23
# False Negatives (FN): 1
# False Positives (FP): 163571
# True Negatives (TN): 1
# Selected SAT: cc
# Number of segments in SAT: 5
#
# Building matrix…
# Similarity matrix dimensions: (5, 163596)
#
# True Positives (TP): 3
# False Negatives (FN): 2
# False Positives (FP): 163533
# True Negatives (TN): 58
# Selected SAT: tranprov
# Number of segments in SAT: 17
#
# Building matrix…
# Similarity matrix dimensions: (17, 163596)
#
# True Positives (TP): 17
# False Negatives (FN): 0
# False Positives (FP): 163542
# True Negatives (TN): 37
# Selected SAT: selfdet
# Number of segments in SAT: 32
#
# Building matrix…
# Similarity matrix dimensions: (32, 163596)
#
# True Positives (TP): 32
# False Negatives (FN): 0
# False Positives (FP): 163564
# True Negatives (TN): 0
# Selected SAT: compvote
# Number of segments in SAT: 11
#
# Building matrix…
# Similarity matrix dimensions: (11, 163596)
#
# True Positives (TP): 5
# False Negatives (FN): 6
# False Positives (FP): 163186
# True Negatives (TN): 399
# Selected SAT: civmar
# Number of segments in SAT: 17
#
# Building matrix…
# Similarity matrix dimensions: (17, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 17
# False Positives (FP): 163218
# True Negatives (TN): 361
# Selected SAT: equalgr14
# Number of segments in SAT: 9
#
# Building matrix…
# Similarity matrix dimensions: (9, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 9
# False Positives (FP): 162002
# True Negatives (TN): 1585
# Selected SAT: ordterm
# Number of segments in SAT: 40
#
# Building matrix…
# Similarity matrix dimensions: (40, 163596)
#
# True Positives (TP): 32
# False Negatives (FN): 8
# False Positives (FP): 163030
# True Negatives (TN): 526
# Selected SAT: ordterml
# Number of segments in SAT: 9
#
# Building matrix…
# Similarity matrix dimensions: (9, 163596)
#
# True Positives (TP): 8
# False Negatives (FN): 1
# False Positives (FP): 161642
# True Negatives (TN): 1945
# Selected SAT: truthcom
# Number of segments in SAT: 4
#
# Building matrix…
# Similarity matrix dimensions: (4, 163596)
#
# True Positives (TP): 4
# False Negatives (FN): 0
# False Positives (FP): 163489
# True Negatives (TN): 103
# Selected SAT: civilmil
# Number of segments in SAT: 4
#
# Building matrix…
# Similarity matrix dimensions: (4, 163596)
#
# True Positives (TP): 2
# False Negatives (FN): 2
# False Positives (FP): 162965
# True Negatives (TN): 627
# Selected SAT: ecrdet
# Number of segments in SAT: 5
#
# Building matrix…
# Similarity matrix dimensions: (5, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 5
# False Positives (FP): 143417
# True Negatives (TN): 20174
# Selected SAT: ecterml
# Number of segments in SAT: 4
#
# Building matrix…
# Similarity matrix dimensions: (4, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 4
# False Positives (FP): 143985
# True Negatives (TN): 19607
# Selected SAT: prisonrg
# Number of segments in SAT: 10
#
# Building matrix…
# Similarity matrix dimensions: (10, 163596)
#
# True Positives (TP): 2
# False Negatives (FN): 8
# False Positives (FP): 161356
# True Negatives (TN): 2230
# Selected SAT: seccess
# Number of segments in SAT: 14
#
# Building matrix…
# Similarity matrix dimensions: (14, 163596)
#
# True Positives (TP): 13
# False Negatives (FN): 1
# False Positives (FP): 163527
# True Negatives (TN): 55
# Selected SAT: colony
# Number of segments in SAT: 10
#
# Building matrix…
# Similarity matrix dimensions: (10, 163596)
#
# True Positives (TP): 10
# False Negatives (FN): 0
# False Positives (FP): 163532
# True Negatives (TN): 54
# Selected SAT: indcit
# Number of segments in SAT: 3
#
# Building matrix…
# Similarity matrix dimensions: (3, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 3
# False Positives (FP): 158421
# True Negatives (TN): 5172
# Selected SAT: indpolgr4
# Number of segments in SAT: 1
#
# Building matrix…
# Similarity matrix dimensions: (1, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 1
# False Positives (FP): 129433
# True Negatives (TN): 34162
# Selected SAT: ordage
# Number of segments in SAT: 19
#
# Building matrix…
# Similarity matrix dimensions: (19, 163596)
#
# True Positives (TP): 17
# False Negatives (FN): 2
# False Positives (FP): 163550
# True Negatives (TN): 27
# Selected SAT: lhtrmlim
# Number of segments in SAT: 2
#
# Building matrix…
# Similarity matrix dimensions: (2, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 2
# False Positives (FP): 152601
# True Negatives (TN): 10993
# Selected SAT: uhtrmlim
# Number of segments in SAT: 3
#
# Building matrix…
# Similarity matrix dimensions: (3, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 3
# False Positives (FP): 153571
# True Negatives (TN): 10022
# Selected SAT: adterm
# Number of segments in SAT: 10
#
# Building matrix…
# Similarity matrix dimensions: (10, 163596)
#
# True Positives (TP): 7
# False Negatives (FN): 3
# False Positives (FP): 162598
# True Negatives (TN): 988
# Selected SAT: adtermn
# Number of segments in SAT: 7
#
# Building matrix…
# Similarity matrix dimensions: (7, 163596)
#
# True Positives (TP): 5
# False Negatives (FN): 2
# False Positives (FP): 160136
# True Negatives (TN): 3453
# Selected SAT: judcrts5
# Number of segments in SAT: 3
#
# Building matrix…
# Similarity matrix dimensions: (3, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 3
# False Positives (FP): 127312
# True Negatives (TN): 36281
# Selected SAT: adage
# Number of segments in SAT: 7
#
# Building matrix…
# Similarity matrix dimensions: (7, 163596)
#
# True Positives (TP): 7
# False Negatives (FN): 0
# False Positives (FP): 163581
# True Negatives (TN): 8
# Selected SAT: preamble
# Number of segments in SAT: 1
#
# Building matrix…
# Similarity matrix dimensions: (1, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 1
# False Positives (FP): 149487
# True Negatives (TN): 14108
# Selected SAT: indpolgr1
# Number of segments in SAT: 9
#
# Building matrix…
# Similarity matrix dimensions: (9, 163596)
#
# True Positives (TP): 5
# False Negatives (FN): 4
# False Positives (FP): 163024
# True Negatives (TN): 563
# Selected SAT: judcrts6
# Number of segments in SAT: 2
#
# Building matrix…
# Similarity matrix dimensions: (2, 163596)
#
# True Positives (TP): 0
# False Negatives (FN): 2
# False Positives (FP): 154171
# True Negatives (TN): 9423
